# %%
import random
import os

from domain_adaptation_ct.dataset.image_dataset import TwoLabelDataset
from domain_adaptation_ct.visualize.imshow_gray import ImShowGray

import numpy as np
import matplotlib.pyplot as plt

# %%
ds = TwoLabelDataset.load("/data/D21_Folds/fold0.npz", convert_grayscale_to_rgb=True)

# %%
len(ds)

# %%
instance = ds[15000]
X = instance['pixel_values']
y = instance['labels1']
d = instance['labels2']
ImShowGray.imshow(np.transpose((X+1)/2, [1, 2, 0]), title=f"labels1={y}, labels2={d}")
